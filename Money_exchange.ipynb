# %% [markdown]
# Task 1
# ---------
# Scrap the USD To EGP Exchange rate from this website
# https://www.exchangerates.org.uk/Dollars-to-Egyptian-Pounds-currency-conversion-page.html
# and then use it to make a software that takes amount of USD Dollars from the user and calculate how much will it cost in EGP.

# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get("https://ca.statebank/home")
print(response.text)
# Out:
#
#
#
# 			<!DOCTYPE html>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <html class="ltr kw kw-SBI-Canada-Bank" dir="ltr" lang="en-US">
#
# <head>
# 	<title>SBI Canada Bank, Personal Banking, Online Banking Services - SBI Canada Bank</title>
#
# 	<meta content="initial-scale=1.0, width=device-width" name="viewport" />
#
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# 	<meta http-equiv="X-UA-Compatible" content="IE=100" />
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <meta content="text/html; charset=UTF-8" http-equiv="content-type" />
#
#
#
#
#
#
#
#
#
# <meta content="SBI Canada Bank, Personal Banking, Online Banking Services" lang="en-US" name="robots" /><meta content="Experience the new age of banking with SBI Canada Bank and enjoy a range of products and services." lang="en-US" name="description" />
#
#
# ...

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
sp = soup.find_all("span", attrs = {"class":"value"})

# %%
sp
# Out:
# [<span class="value"> ₹
#  												60.2
#  											</span>,
#  <span class="value"> $
#  												0.7588
#  											</span>]

# %%
for span in sp:
    # print(span)
    # print(span.get("id"))
    # span = sp[0]
    sp1 = span.get_text().strip()
    # print(sp1)
    ss = sp1.split()
    # print(ss)
    #print(len(ss))
    #print(ss[0])
    #print("In for loop")
    # print(ss[0])
    if(ss[0] == '₹'):
        # print("Ïn if conditon")
        inr = ss[1]
        # print(inr)
        #print("INR " + ss[1])
    elif(ss[0] == '$'):
        # print("In elf condition")
        usd = ss[1]
        #print("USD " + ss[1])
        # print(usd)
    
print(inr)
print(usd)
    #usd = float(ss[1])
#     egp = float(ss[3])
#     type(egp)
    #type(usd)
#     print(egp)
    # print(usd)

while True:
        
    try:
        user1 = input("Do you have INR or USD? Please Write INR or USD only: ")
        if user1 == "INR":
            user_input = float(input("please enter the amount of INR you want to convert: "))
            print("The amount of inr converted to usd is " , user_input/inr)
            break
        elif user1 == "USD":
            user_in_2 = float(input("please enter the amount of USD you want to convert: "))
            print("The amount of Usd converted to usd is " , user_in_2*usd)
            break
    except:
            print("this is not right")
            
else:
    print("not right choice please re-run the prog")
# Out:
# 60.2
# 0.7588
